# %% [markdown]
# Resources Used
# - wget.download('https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/_downloads/da4babe668a8afb093cc7776d7e630f3/generate_tfrecord.py')
# - Setup https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/install.html

# %% [markdown]
# # 0. Setup Paths

# %%
import pandas as pd

# %%
WORKSPACE_PATH = 'Tensorflow/workspace'
SCRIPTS_PATH = 'Tensorflow/scripts'
APIMODEL_PATH = 'Tensorflow/models'
ANNOTATION_PATH = WORKSPACE_PATH+'/annotations'
IMAGE_PATH = WORKSPACE_PATH+'/images'
MODEL_PATH = WORKSPACE_PATH+'/models'
PRETRAINED_MODEL_PATH = WORKSPACE_PATH+'/pre-trained-models'
CONFIG_PATH = MODEL_PATH+'/my_ssd_mobnet/pipeline.config'
CHECKPOINT_PATH = MODEL_PATH+'/my_ssd_mobnet/'

# %% [markdown]
# # 1. Create Label Map

# %%
labels = [{'name':'hello', 'id':1}, 
          {'name':'yes', 'id':2},
          {'name':'no', 'id':3},
          {'name':'thanks', 'id':4},
          {'name':'iloveyou', 'id':5}]

with open(ANNOTATION_PATH + '\label_map.pbtxt', 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 2. Create TF records

# %%
"python Tensorflow/scripts/generate_tfrecord.py -x Tensorflow/workspace/images/train -l Tensorflow/workspace/annotations/train.record"
# Out:
# 'python Tensorflow/scripts/generate_tfrecord.py -x Tensorflow/workspace/images/train -l Tensorflow/workspace/annotations/train.record'

# %%
# !python {SCRIPTS_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/train'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/train.record'}
# !python {SCRIPTS_PATH + '/generate_tfrecord.py'} -x{IMAGE_PATH + '/test'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/test.record'}
# Out:
# Traceback (most recent call last):
#   File "C:\Users\yaswa\OneDrive\Documents\CD\RealTimeObjectDetection\Tensorflow\scripts\generate_tfrecord.py", line 29, in <module>
#     from object_detection.utils import dataset_util, label_map_util
#   File "C:\Users\yaswa\AppData\Local\Programs\Python\Python310\lib\site-packages\object_detection\utils\label_map_util.py", line 21, in <module>
#     from object_detection.protos import string_int_label_map_pb2
#   File "C:\Users\yaswa\AppData\Local\Programs\Python\Python310\lib\site-packages\object_detection\protos\string_int_label_map_pb2.py", line 36, in <module>
#     _descriptor.FieldDescriptor(
#   File "C:\Users\yaswa\AppData\Local\Programs\Python\Python310\lib\site-packages\google\protobuf\descriptor.py", line 621, in __new__
#     _message.Message._CheckCalledFromGeneratedFile()
# TypeError: Descriptors cannot be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates
# Traceback (most recent call last):
#   File "C:\Users\yaswa\OneDrive\Documents\CD\RealTimeObjectDetection\Tensorflow\scripts\generate_tfrecord.py", line 29, in <module>
#     from object_detection.utils import dataset_util, label_map_util
#   File "C:\Users\yaswa\AppData\Local\Programs\Python\Python310\lib\site-packages\object_detection\utils\label_map_util.py", line 21, in <module>
#     from object_detection.protos import string_int_label_map_pb2
#   File "C:\Users\yaswa\AppData\Local\Programs\Python\Python310\lib\site-packages\object_detection\protos\string_int_label_map_pb2.py", line 36, in <module>
#     _descriptor.FieldDescriptor(
#   File "C:\Users\yaswa\AppData\Local\Programs\Python\Python310\lib\site-packages\google\protobuf\descriptor.py", line 621, in __new__
#     _message.Message._CheckCalledFromGeneratedFile()
# TypeError: Descriptors cannot be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %% [markdown]
# 3. Download TF Models Pretrained Models from Tensorflow Model Zoo

# %%
pip install object-detection
# Out:
# Collecting object-detection
#   Using cached object_detection-0.0.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tensorflow in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from object-detection) (2.16.1)
# Collecting Cython (from object-detection)
#   Downloading Cython-3.0.10-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# Collecting contextlib2 (from object-detection)
#   Using cached contextlib2-21.6.0-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: pillow in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from object-detection) (10.0.1)
# Requirement already satisfied: lxml in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from object-detection) (5.2.0)
# Requirement already satisfied: jupyter in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from object-detection) (1.0.0)
# Requirement already satisfied: matplotlib in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from object-detection) (3.8.0)
# Requirement already satisfied: notebook in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter->object-detection) (7.0.5)
# Requirement already satisfied: qtconsole in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter->object-detection) (5.4.4)
# Requirement already satisfied: jupyter-console in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter->object-detection) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter->object-detection) (7.9.2)
# Requirement already satisfied: ipykernel in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter->object-detection) (6.25.2)
# Requirement already satisfied: ipywidgets in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter->object-detection) (8.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->object-detection) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->object-detection) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->object-detection) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->object-detection) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->object-detection) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->object-detection) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->object-detection) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->object-detection) (2.8.2)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow->object-detection) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (69.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->object-detection) (3.2.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->object-detection) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->object-detection) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->object-detection) (8.16.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->object-detection) (8.4.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->object-detection) (5.4.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->object-detection) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->object-detection) (1.5.8)
# Requirement already satisfied: psutil in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->object-detection) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->object-detection) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->object-detection) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter->object-detection) (5.11.2)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets->jupyter->object-detection) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets->jupyter->object-detection) (3.0.9)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-console->jupyter->object-detection) (3.0.39)
# Requirement already satisfied: pygments in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-console->jupyter->object-detection) (2.16.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->object-detection) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->object-detection) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->object-detection) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->object-detection) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->object-detection) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->object-detection) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->object-detection) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->object-detection) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->object-detection) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->object-detection) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter->object-detection) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from notebook->jupyter->object-detection) (2.7.3)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from notebook->jupyter->object-detection) (2.25.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from notebook->jupyter->object-detection) (4.0.7)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from notebook->jupyter->object-detection) (0.2.3)
# Requirement already satisfied: ipython-genutils in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from qtconsole->jupyter->object-detection) (0.2.0)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from qtconsole->jupyter->object-detection) (2.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow->object-detection) (0.43.0)
# Requirement already satisfied: webencodings in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->object-detection) (0.5.1)
# Requirement already satisfied: backcall in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object-detection) (0.2.0)
# Requirement already satisfied: decorator in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object-detection) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object-detection) (0.19.1)
# Requirement already satisfied: pickleshare in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object-detection) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object-detection) (0.6.3)
# Requirement already satisfied: colorama in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object-detection) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->object-detection) (3.11.0)
# Requirement already satisfied: pywin32>=300 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->object-detection) (306)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (4.0.0)
# Requirement already satisfied: argon2-cffi in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (0.7.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (0.4.4)
# Requirement already satisfied: overrides in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (0.17.1)
# Requirement already satisfied: pywinpty in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (2.0.12)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (1.6.4)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->object-detection) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->object-detection) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->object-detection) (2.13.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->object-detection) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->object-detection) (4.19.1)
# Requirement already satisfied: rich in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow->object-detection) (13.7.1)
# Requirement already satisfied: namex in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow->object-detection) (0.0.7)
# Requirement already satisfied: optree in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow->object-detection) (0.11.0)
# Requirement already satisfied: fastjsonschema in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter->object-detection) (2.18.1)
# Requirement already satisfied: wcwidth in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->object-detection) (0.2.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow->object-detection) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow->object-detection) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow->object-detection) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow->object-detection) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow->object-detection) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow->object-detection) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow->object-detection) (3.0.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->object-detection) (2.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->object-detection) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->object-detection) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->object-detection) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->object-detection) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->object-detection) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (0.1.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (21.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow->object-detection) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->object-detection) (2.0.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->object-detection) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->object-detection) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (2.4)
# Requirement already satisfied: uri-template in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (1.13)
# Requirement already satisfied: mdurl~=0.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow->object-detection) (0.1.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\yaswa\appdata\local\programs\python\python312\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->object-detection) (2.8.19.14)
# Using cached object_detection-0.0.3-py3-none-any.whl (1.5 MB)
# Using cached contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Downloading Cython-3.0.10-cp312-cp312-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------ --------------------------------- 0.4/2.8 MB 9.3 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/2.8 MB 10.6 MB/s eta 0:00:01
#    --------------------- ------------------ 1.5/2.8 MB 12.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.1/2.8 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------ --- 2.5/2.8 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 10.5 MB/s eta 0:00:00
# Installing collected packages: Cython, contextlib2, object-detection
# Successfully installed Cython-3.0.10 contextlib2-21.6.0 object-detection-0.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# !cd Tensorflow && git clone https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# Updating files:  65% (2413/3699)
# Updating files:  66% (2442/3699)
# Updating files:  67% (2479/3699)
# Updating files:  68% (2516/3699)
# Updating files:  69% (2553/3699)
# Updating files:  70% (2590/3699)
# Updating files:  71% (2627/3699)
# Updating files:  72% (2664/3699)
# Updating files:  73% (2701/3699)
# Updating files:  74% (2738/3699)
# Updating files:  75% (2775/3699)
# Updating files:  76% (2812/3699)
# Updating files:  77% (2849/3699)
# Updating files:  78% (2886/3699)
# Updating files:  79% (2923/3699)
# Updating files:  80% (2960/3699)
# Updating files:  81% (2997/3699)
# Updating files:  82% (3034/3699)
# Updating files:  83% (3071/3699)
# Updating files:  84% (3108/3699)
# Updating files:  85% (3145/3699)
# Updating files:  86% (3182/3699)
# Updating files:  87% (3219/3699)
# Updating files:  88% (3256/3699)
# Updating files:  89% (3293/3699)
# Updating files:  90% (3330/3699)
# Updating files:  91% (3367/3699)
# Updating files:  92% (3404/3699)
# Updating files:  93% (3441/3699)
# Updating files:  94% (3478/3699)
# Updating files:  95% (3515/3699)
# Updating files:  96% (3552/3699)
# Updating files:  97% (3589/3699)
# Updating files:  98% (3626/3699)
# Updating files:  99% (3663/3699)
# Updating files: 100% (3699/3699)
# Updating files: 100% (3699/3699), done.

# %%
#wget.download('http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz')
#!mv ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz {PRETRAINED_MODEL_PATH}
#!cd {PRETRAINED_MODEL_PATH} && tar -zxvf ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet'

# %%
# !mkdir {'Tensorflow\workspace\models\\'+CUSTOM_MODEL_NAME}
# Out:
# A subdirectory or file Tensorflow\workspace\models\my_ssd_mobnet already exists.

# %%
# !mkdir {'Tensorflow\workspace\models\\'+CUSTOM_MODEL_NAME}
# !cp {PRETRAINED_MODEL_PATH+'/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config'} {MODEL_PATH+'/'+CUSTOM_MODEL_NAME}
# Out:
#   Cell In[12], line 2
#     //!cp {PRETRAINED_MODEL_PATH+'/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config'} {MODEL_PATH+'/'+CUSTOM_MODEL_NAME}
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
pip install tensorflow-object-detection-api
# Out:
# Requirement already satisfied: tensorflow-object-detection-api in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (0.1.1)
# Requirement already satisfied: Pillow>=1.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (10.3.0)
# Requirement already satisfied: Matplotlib>=2.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (3.8.4)
# Requirement already satisfied: Cython>=0.28.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (3.0.10)
# Requirement already satisfied: Protobuf in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (5.26.1)
# Requirement already satisfied: lxml in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (5.2.1)
# Requirement already satisfied: jupyter in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (1.0.0)
# Requirement already satisfied: tensorflow in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (2.16.1)
# Requirement already satisfied: contextlib2 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (21.6.0)
# Requirement already satisfied: wheel in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (0.43.0)
# Requirement already satisfied: twine in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (5.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (2.9.0.post0)
# Requirement already satisfied: notebook in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter->tensorflow-object-detection-api) (7.1.2)
# Requirement already satisfied: qtconsole in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter->tensorflow-object-detection-api) (5.5.1)
# Requirement already satisfied: jupyter-console in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter->tensorflow-object-detection-api) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter->tensorflow-object-detection-api) (7.16.3)
# Requirement already satisfied: ipykernel in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter->tensorflow-object-detection-api) (6.29.4)
# Requirement already satisfied: ipywidgets in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter->tensorflow-object-detection-api) (8.1.2)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (3.3.0)
# Collecting Protobuf (from tensorflow-object-detection-api)
#   Using cached protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (3.2.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (0.31.0)
# Requirement already satisfied: pkginfo>=1.8.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from twine->tensorflow-object-detection-api) (1.10.0)
# Requirement already satisfied: readme-renderer>=35.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from twine->tensorflow-object-detection-api) (43.0)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from twine->tensorflow-object-detection-api) (1.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from twine->tensorflow-object-detection-api) (2.2.1)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from twine->tensorflow-object-detection-api) (7.1.0)
# Requirement already satisfied: keyring>=15.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from twine->tensorflow-object-detection-api) (25.1.0)
# Requirement already satisfied: rfc3986>=1.4.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from twine->tensorflow-object-detection-api) (2.0.0)
# Requirement already satisfied: rich>=12.0.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from twine->tensorflow-object-detection-api) (13.7.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=3.6->twine->tensorflow-object-detection-api) (3.18.1)
# Requirement already satisfied: jaraco.classes in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from keyring>=15.1->twine->tensorflow-object-detection-api) (3.4.0)
# Requirement already satisfied: jaraco.functools in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from keyring>=15.1->twine->tensorflow-object-detection-api) (4.0.0)
# Requirement already satisfied: jaraco.context in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from keyring>=15.1->twine->tensorflow-object-detection-api) (5.3.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from keyring>=15.1->twine->tensorflow-object-detection-api) (0.2.2)
# Requirement already satisfied: nh3>=0.2.14 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from readme-renderer>=35.0->twine->tensorflow-object-detection-api) (0.2.17)
# Requirement already satisfied: docutils>=0.13.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from readme-renderer>=35.0->twine->tensorflow-object-detection-api) (0.21.1)
# Requirement already satisfied: Pygments>=2.5.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from readme-renderer>=35.0->twine->tensorflow-object-detection-api) (2.17.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from rich>=12.0.0->twine->tensorflow-object-detection-api) (3.0.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (8.23.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (8.6.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (1.6.0)
# Requirement already satisfied: psutil in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (26.0.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (5.14.2)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->jupyter->tensorflow-object-detection-api) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->jupyter->tensorflow-object-detection-api) (3.0.10)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-console->jupyter->tensorflow-object-detection-api) (3.0.43)
# Requirement already satisfied: beautifulsoup4 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (3.1.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from notebook->jupyter->tensorflow-object-detection-api) (2.14.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from notebook->jupyter->tensorflow-object-detection-api) (2.26.0)
# Requirement already satisfied: jupyterlab<4.2,>=4.1.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from notebook->jupyter->tensorflow-object-detection-api) (4.1.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from notebook->jupyter->tensorflow-object-detection-api) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from qtconsole->jupyter->tensorflow-object-detection-api) (2.4.1)
# Requirement already satisfied: webencodings in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->tensorflow-object-detection-api) (0.5.1)
# Requirement already satisfied: decorator in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.6.3)
# Requirement already satisfied: exceptiongroup in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (1.2.0)
# Requirement already satisfied: colorama in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->tensorflow-object-detection-api) (4.2.0)
# Requirement already satisfied: pywin32>=300 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->tensorflow-object-detection-api) (306)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (4.3.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.20.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (2.0.13)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->tensorflow-object-detection-api) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->tensorflow-object-detection-api) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->tensorflow-object-detection-api) (2.2.5)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->tensorflow-object-detection-api) (2.0.1)
# Requirement already satisfied: babel>=2.10 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (4.21.1)
# Requirement already satisfied: namex in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (0.0.7)
# Requirement already satisfied: optree in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (0.11.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->tensorflow-object-detection-api) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter->tensorflow-object-detection-api) (2.19.1)
# Requirement already satisfied: wcwidth in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->tensorflow-object-detection-api) (0.2.13)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (3.0.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->tensorflow-object-detection-api) (2.5)
# Requirement already satisfied: more-itertools in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jaraco.classes->keyring>=15.1->twine->tensorflow-object-detection-api) (10.2.0)
# Requirement already satisfied: backports.tarfile in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jaraco.context->keyring>=15.1->twine->tensorflow-object-detection-api) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (21.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter->tensorflow-object-detection-api) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter->tensorflow-object-detection-api) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (0.18.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.1.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (2.4)
# Requirement already satisfied: uri-template in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (2.9.0.20240316)
# Using cached protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
# Installing collected packages: Protobuf
#   Attempting uninstall: Protobuf
#     Found existing installation: protobuf 5.26.1
#     Uninstalling protobuf-5.26.1:
#       Successfully uninstalled protobuf-5.26.1
# Successfully installed Protobuf-4.25.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.11 requires protobuf<4,>=3.11, but you have protobuf 4.25.3 which is incompatible.

# %%
pip install --upgrade protobuf
# Out:
# Requirement already satisfied: protobuf in c:\users\yaswa\appdata\local\programs\python\python310\lib\site-packages (4.25.3)
# Collecting protobuf
#   Using cached protobuf-5.26.1-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Using cached protobuf-5.26.1-cp310-abi3-win_amd64.whl (420 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
# Successfully installed protobuf-5.26.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\yaswa\AppData\Local\Programs\Python\Python310\Lib\site-packages\google\~upb'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.11 requires protobuf<4,>=3.11, but you have protobuf 5.26.1 which is incompatible.
# tensorflow-intel 2.16.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.26.1 which is incompatible.

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 import tensorflow as tf
# ----> 2 from object_detection.utils import config_util
#       3 from object_detection.protos import pipeline_pb2
#       4 from google.protobuf import text_format
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\object_detection\utils\config_util.py:24
#      20 from google.protobuf import text_format
#      22 from tensorflow.python.lib.io import file_io
# ---> 24 from object_detection.protos import eval_pb2
#      25 from object_detection.protos import graph_rewriter_pb2
#      26 from object_detection.protos import input_reader_pb2
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\object_detection\protos\eval_pb2.py:36
#      13 _sym_db = _symbol_database.Default()
#      18 DESCRIPTOR = _descriptor.FileDescriptor(
#      19   name='object_detection/protos/eval.proto',
#      20   package='object_detection.protos',
#    (...)
#      23   serialized_pb=_b('\n\"object_detection/protos/eval.proto\x12\x17object_detection.protos\"\xf7\x05\n\nEvalConfig\x12\x15\n\nbatch_size\x18\x19 \x01(\r:\x01\x31\x12\x1e\n\x12num_visualizations\x18\x01 \x01(\r:\x02\x31\x30\x12\x1e\n\x0cnum_examples\x18\x02 \x01(\r:\x04\x35\x30\x30\x30\x42\x02\x18\x01\x12\x1f\n\x12\x65val_interval_secs\x18\x03 \x01(\r:\x03\x33\x30\x30\x12\x18\n\tmax_evals\x18\x04 \x01(\r:\x01\x30\x42\x02\x18\x01\x12\x19\n\nsave_graph\x18\x05 \x01(\x08:\x05\x66\x61lse\x12\"\n\x18visualization_export_dir\x18\x06 \x01(\t:\x00\x12\x15\n\x0b\x65val_master\x18\x07 \x01(\t:\x00\x12\x13\n\x0bmetrics_set\x18\x08 \x03(\t\x12\x15\n\x0b\x65xport_path\x18\t \x01(\t:\x00\x12!\n\x12ignore_groundtruth\x18\n \x01(\x08:\x05\x66\x61lse\x12\"\n\x13use_moving_averages\x18\x0b \x01(\x08:\x05\x66\x61lse\x12\"\n\x13\x65val_instance_masks\x18\x0c \x01(\x08:\x05\x66\x61lse\x12 \n\x13min_score_threshold\x18\r \x01(\x02:\x03\x30.5\x12&\n\x1amax_num_boxes_to_visualize\x18\x0e \x01(\x05:\x02\x32\x30\x12\x1a\n\x0bskip_scores\x18\x0f \x01(\x08:\x05\x66\x61lse\x12\x1a\n\x0bskip_labels\x18\x10 \x01(\x08:\x05\x66\x61lse\x12*\n\x1bvisualize_groundtruth_boxes\x18\x11 \x01(\x08:\x05\x66\x61lse\x12\x32\n#groundtruth_box_visualization_color\x18\x12 \x01(\t:\x05\x62lack\x12\x35\n&keep_image_id_for_visualization_export\x18\x13 \x01(\x08:\x05\x66\x61lse\x12$\n\x16retain_original_images\x18\x17 \x01(\x08:\x04true\x12+\n\x1cinclude_metrics_per_category\x18\x18 \x01(\x08:\x05\x66\x61lse')
#      24 )
#      29 _EVALCONFIG = _descriptor.Descriptor(
#      30   name='EvalConfig',
#      31   full_name='object_detection.protos.EvalConfig',
#      32   filename=None,
#      33   file=DESCRIPTOR,
#      34   containing_type=None,
#      35   fields=[
# ---> 36     _descriptor.FieldDescriptor(
#      37       name='batch_size', full_name='object_detection.protos.EvalConfig.batch_size', index=0,
#      38       number=25, type=13, cpp_type=3, label=1,
#      39       has_default_value=True, default_value=1,
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
#      42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='num_visualizations', full_name='object_detection.protos.EvalConfig.num_visualizations', index=1,
#      45       number=1, type=13, cpp_type=3, label=1,
#      46       has_default_value=True, default_value=10,
#      47       message_type=None, enum_type=None, containing_type=None,
#      48       is_extension=False, extension_scope=None,
#      49       serialized_options=None, file=DESCRIPTOR),
#      50     _descriptor.FieldDescriptor(
#      51       name='num_examples', full_name='object_detection.protos.EvalConfig.num_examples', index=2,
#      52       number=2, type=13, cpp_type=3, label=1,
#      53       has_default_value=True, default_value=5000,
#      54       message_type=None, enum_type=None, containing_type=None,
#      55       is_extension=False, extension_scope=None,
#      56       serialized_options=_b('\030\001'), file=DESCRIPTOR),
#      57     _descriptor.FieldDescriptor(
#      58       name='eval_interval_secs', full_name='object_detection.protos.EvalConfig.eval_interval_secs', index=3,
#      59       number=3, type=13, cpp_type=3, label=1,
#      60       has_default_value=True, default_value=300,
#      61       message_type=None, enum_type=None, containing_type=None,
#      62       is_extension=False, extension_scope=None,
#      63       serialized_options=None, file=DESCRIPTOR),
#      64     _descriptor.FieldDescriptor(
#      65       name='max_evals', full_name='object_detection.protos.EvalConfig.max_evals', index=4,
#      66       number=4, type=13, cpp_type=3, label=1,
#      67       has_default_value=True, default_value=0,
#      68       message_type=None, enum_type=None, containing_type=None,
#      69       is_extension=False, extension_scope=None,
#      70       serialized_options=_b('\030\001'), file=DESCRIPTOR),
#      71     _descriptor.FieldDescriptor(
#      72       name='save_graph', full_name='object_detection.protos.EvalConfig.save_graph', index=5,
#      73       number=5, type=8, cpp_type=7, label=1,
#      74       has_default_value=True, default_value=False,
#      75       message_type=None, enum_type=None, containing_type=None,
#      76       is_extension=False, extension_scope=None,
#      77       serialized_options=None, file=DESCRIPTOR),
#      78     _descriptor.FieldDescriptor(
#      79       name='visualization_export_dir', full_name='object_detection.protos.EvalConfig.visualization_export_dir', index=6,
#      80       number=6, type=9, cpp_type=9, label=1,
#      81       has_default_value=True, default_value=_b("").decode('utf-8'),
#      82       message_type=None, enum_type=None, containing_type=None,
#      83       is_extension=False, extension_scope=None,
#      84       serialized_options=None, file=DESCRIPTOR),
#      85     _descriptor.FieldDescriptor(
#      86       name='eval_master', full_name='object_detection.protos.EvalConfig.eval_master', index=7,
#      87       number=7, type=9, cpp_type=9, label=1,
#      88       has_default_value=True, default_value=_b("").decode('utf-8'),
#      89       message_type=None, enum_type=None, containing_type=None,
#      90       is_extension=False, extension_scope=None,
#      91       serialized_options=None, file=DESCRIPTOR),
#      92     _descriptor.FieldDescriptor(
#      93       name='metrics_set', full_name='object_detection.protos.EvalConfig.metrics_set', index=8,
#      94       number=8, type=9, cpp_type=9, label=3,
#      95       has_default_value=False, default_value=[],
#      96       message_type=None, enum_type=None, containing_type=None,
#      97       is_extension=False, extension_scope=None,
#      98       serialized_options=None, file=DESCRIPTOR),
#      99     _descriptor.FieldDescriptor(
#     100       name='export_path', full_name='object_detection.protos.EvalConfig.export_path', index=9,
#     101       number=9, type=9, cpp_type=9, label=1,
#     102       has_default_value=True, default_value=_b("").decode('utf-8'),
#     103       message_type=None, enum_type=None, containing_type=None,
#     104       is_extension=False, extension_scope=None,
#     105       serialized_options=None, file=DESCRIPTOR),
#     106     _descriptor.FieldDescriptor(
#     107       name='ignore_groundtruth', full_name='object_detection.protos.EvalConfig.ignore_groundtruth', index=10,
#     108       number=10, type=8, cpp_type=7, label=1,
#     109       has_default_value=True, default_value=False,
#     110       message_type=None, enum_type=None, containing_type=None,
#     111       is_extension=False, extension_scope=None,
#     112       serialized_options=None, file=DESCRIPTOR),
#     113     _descriptor.FieldDescriptor(
#     114       name='use_moving_averages', full_name='object_detection.protos.EvalConfig.use_moving_averages', index=11,
#     115       number=11, type=8, cpp_type=7, label=1,
#     116       has_default_value=True, default_value=False,
#     117       message_type=None, enum_type=None, containing_type=None,
#     118       is_extension=False, extension_scope=None,
#     119       serialized_options=None, file=DESCRIPTOR),
#     120     _descriptor.FieldDescriptor(
#     121       name='eval_instance_masks', full_name='object_detection.protos.EvalConfig.eval_instance_masks', index=12,
#     122       number=12, type=8, cpp_type=7, label=1,
#     123       has_default_value=True, default_value=False,
#     124       message_type=None, enum_type=None, containing_type=None,
#     125       is_extension=False, extension_scope=None,
#     126       serialized_options=None, file=DESCRIPTOR),
#     127     _descriptor.FieldDescriptor(
#     128       name='min_score_threshold', full_name='object_detection.protos.EvalConfig.min_score_threshold', index=13,
#     129       number=13, type=2, cpp_type=6, label=1,
#     130       has_default_value=True, default_value=float(0.5),
#     131       message_type=None, enum_type=None, containing_type=None,
#     132       is_extension=False, extension_scope=None,
#     133       serialized_options=None, file=DESCRIPTOR),
#     134     _descriptor.FieldDescriptor(
#     135       name='max_num_boxes_to_visualize', full_name='object_detection.protos.EvalConfig.max_num_boxes_to_visualize', index=14,
#     136       number=14, type=5, cpp_type=1, label=1,
#     137       has_default_value=True, default_value=20,
#     138       message_type=None, enum_type=None, containing_type=None,
#     139       is_extension=False, extension_scope=None,
#     140       serialized_options=None, file=DESCRIPTOR),
#     141     _descriptor.FieldDescriptor(
#     142       name='skip_scores', full_name='object_detection.protos.EvalConfig.skip_scores', index=15,
#     143       number=15, type=8, cpp_type=7, label=1,
#     144       has_default_value=True, default_value=False,
#     145       message_type=None, enum_type=None, containing_type=None,
#     146       is_extension=False, extension_scope=None,
#     147       serialized_options=None, file=DESCRIPTOR),
#     148     _descriptor.FieldDescriptor(
#     149       name='skip_labels', full_name='object_detection.protos.EvalConfig.skip_labels', index=16,
#     150       number=16, type=8, cpp_type=7, label=1,
#     151       has_default_value=True, default_value=False,
#     152       message_type=None, enum_type=None, containing_type=None,
#     153       is_extension=False, extension_scope=None,
#     154       serialized_options=None, file=DESCRIPTOR),
#     155     _descriptor.FieldDescriptor(
#     156       name='visualize_groundtruth_boxes', full_name='object_detection.protos.EvalConfig.visualize_groundtruth_boxes', index=17,
#     157       number=17, type=8, cpp_type=7, label=1,
#     158       has_default_value=True, default_value=False,
#     159       message_type=None, enum_type=None, containing_type=None,
#     160       is_extension=False, extension_scope=None,
#     161       serialized_options=None, file=DESCRIPTOR),
#     162     _descriptor.FieldDescriptor(
#     163       name='groundtruth_box_visualization_color', full_name='object_detection.protos.EvalConfig.groundtruth_box_visualization_color', index=18,
#     164       number=18, type=9, cpp_type=9, label=1,
#     165       has_default_value=True, default_value=_b("black").decode('utf-8'),
#     166       message_type=None, enum_type=None, containing_type=None,
#     167       is_extension=False, extension_scope=None,
#     168       serialized_options=None, file=DESCRIPTOR),
#     169     _descriptor.FieldDescriptor(
#     170       name='keep_image_id_for_visualization_export', full_name='object_detection.protos.EvalConfig.keep_image_id_for_visualization_export', index=19,
#     171       number=19, type=8, cpp_type=7, label=1,
#     172       has_default_value=True, default_value=False,
#     173       message_type=None, enum_type=None, containing_type=None,
#     174       is_extension=False, extension_scope=None,
#     175       serialized_options=None, file=DESCRIPTOR),
#     176     _descriptor.FieldDescriptor(
#     177       name='retain_original_images', full_name='object_detection.protos.EvalConfig.retain_original_images', index=20,
#     178       number=23, type=8, cpp_type=7, label=1,
#     179       has_default_value=True, default_value=True,
#     180       message_type=None, enum_type=None, containing_type=None,
#     181       is_extension=False, extension_scope=None,
#     182       serialized_options=None, file=DESCRIPTOR),
#     183     _descriptor.FieldDescriptor(
#     184       name='include_metrics_per_category', full_name='object_detection.protos.EvalConfig.include_metrics_per_category', index=21,
#     185       number=24, type=8, cpp_type=7, label=1,
#     186       has_default_value=True, default_value=False,
#     187       message_type=None, enum_type=None, containing_type=None,
#     188       is_extension=False, extension_scope=None,
#     189       serialized_options=None, file=DESCRIPTOR),
#     190   ],
#     191   extensions=[
#     192   ],
#     193   nested_types=[],
#     194   enum_types=[
#     195   ],
#     196   serialized_options=None,
#     197   is_extendable=False,
#     198   syntax='proto2',
#     199   extension_ranges=[],
#     200   oneofs=[
#     201   ],
#     202   serialized_start=64,
#     203   serialized_end=823,
#     204 )
#     206 DESCRIPTOR.message_types_by_name['EvalConfig'] = _EVALCONFIG
#     207 _sym_db.RegisterFileDescriptor(DESCRIPTOR)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\google\protobuf\descriptor.py:553, in FieldDescriptor.__new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     547 def __new__(cls, name, full_name, index, number, type, cpp_type, label,
#     548             default_value, message_type, enum_type, containing_type,
#     549             is_extension, extension_scope, options=None,
#     550             serialized_options=None,
#     551             has_default_value=True, containing_oneof=None, json_name=None,
#     552             file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 553   _message.Message._CheckCalledFromGeneratedFile()
#     554   if is_extension:
#     555     return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %%
CONFIG_PATH = MODEL_PATH+'/'+CUSTOM_MODEL_NAME+'/pipeline.config'

# %%
config = config_util.get_configs_from_pipeline_file(CONFIG_PATH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 config = config_util.get_configs_from_pipeline_file(CONFIG_PATH)
#
# NameError: name 'config_util' is not defined

# %%
config
# Out:
# Available objects for config:
#     AliasManager
#     DisplayFormatter
#     HistoryManager
#     IPCompleter
#     IPKernelApp
#     LoggingMagics
#     MagicsManager
#     OSMagics
#     PrefilterManager
#     ScriptMagics
#     StoreMagics
#     ZMQInteractiveShell

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(CONFIG_PATH, "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
#       2 with tf.io.gfile.GFile(CONFIG_PATH, "r") as f:
#       3     proto_str = f.read()
#
# NameError: name 'pipeline_pb2' is not defined

# %%
import tensorflow as tf
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# Assuming CONFIG_PATH is the path to your pipeline configuration file
CONFIG_PATH = "path/to/your/config.pbtxt"

pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(CONFIG_PATH, "r") as f:
    proto_str = f.read()
    text_format.Merge(proto_str, pipeline_config)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 import tensorflow as tf
# ----> 2 from object_detection.protos import pipeline_pb2
#       3 from google.protobuf import text_format
#       5 # Assuming CONFIG_PATH is the path to your pipeline configuration file
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\object_detection\protos\pipeline_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from object_detection.protos import eval_pb2 as object__detection_dot_protos_dot_eval__pb2
#      17 from object_detection.protos import graph_rewriter_pb2 as object__detection_dot_protos_dot_graph__rewriter__pb2
#      18 from object_detection.protos import input_reader_pb2 as object__detection_dot_protos_dot_input__reader__pb2
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\object_detection\protos\eval_pb2.py:36
#      13 _sym_db = _symbol_database.Default()
#      18 DESCRIPTOR = _descriptor.FileDescriptor(
#      19   name='object_detection/protos/eval.proto',
#      20   package='object_detection.protos',
#    (...)
#      23   serialized_pb=_b('\n\"object_detection/protos/eval.proto\x12\x17object_detection.protos\"\xf7\x05\n\nEvalConfig\x12\x15\n\nbatch_size\x18\x19 \x01(\r:\x01\x31\x12\x1e\n\x12num_visualizations\x18\x01 \x01(\r:\x02\x31\x30\x12\x1e\n\x0cnum_examples\x18\x02 \x01(\r:\x04\x35\x30\x30\x30\x42\x02\x18\x01\x12\x1f\n\x12\x65val_interval_secs\x18\x03 \x01(\r:\x03\x33\x30\x30\x12\x18\n\tmax_evals\x18\x04 \x01(\r:\x01\x30\x42\x02\x18\x01\x12\x19\n\nsave_graph\x18\x05 \x01(\x08:\x05\x66\x61lse\x12\"\n\x18visualization_export_dir\x18\x06 \x01(\t:\x00\x12\x15\n\x0b\x65val_master\x18\x07 \x01(\t:\x00\x12\x13\n\x0bmetrics_set\x18\x08 \x03(\t\x12\x15\n\x0b\x65xport_path\x18\t \x01(\t:\x00\x12!\n\x12ignore_groundtruth\x18\n \x01(\x08:\x05\x66\x61lse\x12\"\n\x13use_moving_averages\x18\x0b \x01(\x08:\x05\x66\x61lse\x12\"\n\x13\x65val_instance_masks\x18\x0c \x01(\x08:\x05\x66\x61lse\x12 \n\x13min_score_threshold\x18\r \x01(\x02:\x03\x30.5\x12&\n\x1amax_num_boxes_to_visualize\x18\x0e \x01(\x05:\x02\x32\x30\x12\x1a\n\x0bskip_scores\x18\x0f \x01(\x08:\x05\x66\x61lse\x12\x1a\n\x0bskip_labels\x18\x10 \x01(\x08:\x05\x66\x61lse\x12*\n\x1bvisualize_groundtruth_boxes\x18\x11 \x01(\x08:\x05\x66\x61lse\x12\x32\n#groundtruth_box_visualization_color\x18\x12 \x01(\t:\x05\x62lack\x12\x35\n&keep_image_id_for_visualization_export\x18\x13 \x01(\x08:\x05\x66\x61lse\x12$\n\x16retain_original_images\x18\x17 \x01(\x08:\x04true\x12+\n\x1cinclude_metrics_per_category\x18\x18 \x01(\x08:\x05\x66\x61lse')
#      24 )
#      29 _EVALCONFIG = _descriptor.Descriptor(
#      30   name='EvalConfig',
#      31   full_name='object_detection.protos.EvalConfig',
#      32   filename=None,
#      33   file=DESCRIPTOR,
#      34   containing_type=None,
#      35   fields=[
# ---> 36     _descriptor.FieldDescriptor(
#      37       name='batch_size', full_name='object_detection.protos.EvalConfig.batch_size', index=0,
#      38       number=25, type=13, cpp_type=3, label=1,
#      39       has_default_value=True, default_value=1,
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
#      42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='num_visualizations', full_name='object_detection.protos.EvalConfig.num_visualizations', index=1,
#      45       number=1, type=13, cpp_type=3, label=1,
#      46       has_default_value=True, default_value=10,
#      47       message_type=None, enum_type=None, containing_type=None,
#      48       is_extension=False, extension_scope=None,
#      49       serialized_options=None, file=DESCRIPTOR),
#      50     _descriptor.FieldDescriptor(
#      51       name='num_examples', full_name='object_detection.protos.EvalConfig.num_examples', index=2,
#      52       number=2, type=13, cpp_type=3, label=1,
#      53       has_default_value=True, default_value=5000,
#      54       message_type=None, enum_type=None, containing_type=None,
#      55       is_extension=False, extension_scope=None,
#      56       serialized_options=_b('\030\001'), file=DESCRIPTOR),
#      57     _descriptor.FieldDescriptor(
#      58       name='eval_interval_secs', full_name='object_detection.protos.EvalConfig.eval_interval_secs', index=3,
#      59       number=3, type=13, cpp_type=3, label=1,
#      60       has_default_value=True, default_value=300,
#      61       message_type=None, enum_type=None, containing_type=None,
#      62       is_extension=False, extension_scope=None,
#      63       serialized_options=None, file=DESCRIPTOR),
#      64     _descriptor.FieldDescriptor(
#      65       name='max_evals', full_name='object_detection.protos.EvalConfig.max_evals', index=4,
#      66       number=4, type=13, cpp_type=3, label=1,
#      67       has_default_value=True, default_value=0,
#      68       message_type=None, enum_type=None, containing_type=None,
#      69       is_extension=False, extension_scope=None,
#      70       serialized_options=_b('\030\001'), file=DESCRIPTOR),
#      71     _descriptor.FieldDescriptor(
#      72       name='save_graph', full_name='object_detection.protos.EvalConfig.save_graph', index=5,
#      73       number=5, type=8, cpp_type=7, label=1,
#      74       has_default_value=True, default_value=False,
#      75       message_type=None, enum_type=None, containing_type=None,
#      76       is_extension=False, extension_scope=None,
#      77       serialized_options=None, file=DESCRIPTOR),
#      78     _descriptor.FieldDescriptor(
#      79       name='visualization_export_dir', full_name='object_detection.protos.EvalConfig.visualization_export_dir', index=6,
#      80       number=6, type=9, cpp_type=9, label=1,
#      81       has_default_value=True, default_value=_b("").decode('utf-8'),
#      82       message_type=None, enum_type=None, containing_type=None,
#      83       is_extension=False, extension_scope=None,
#      84       serialized_options=None, file=DESCRIPTOR),
#      85     _descriptor.FieldDescriptor(
#      86       name='eval_master', full_name='object_detection.protos.EvalConfig.eval_master', index=7,
#      87       number=7, type=9, cpp_type=9, label=1,
#      88       has_default_value=True, default_value=_b("").decode('utf-8'),
#      89       message_type=None, enum_type=None, containing_type=None,
#      90       is_extension=False, extension_scope=None,
#      91       serialized_options=None, file=DESCRIPTOR),
#      92     _descriptor.FieldDescriptor(
#      93       name='metrics_set', full_name='object_detection.protos.EvalConfig.metrics_set', index=8,
#      94       number=8, type=9, cpp_type=9, label=3,
#      95       has_default_value=False, default_value=[],
#      96       message_type=None, enum_type=None, containing_type=None,
#      97       is_extension=False, extension_scope=None,
#      98       serialized_options=None, file=DESCRIPTOR),
#      99     _descriptor.FieldDescriptor(
#     100       name='export_path', full_name='object_detection.protos.EvalConfig.export_path', index=9,
#     101       number=9, type=9, cpp_type=9, label=1,
#     102       has_default_value=True, default_value=_b("").decode('utf-8'),
#     103       message_type=None, enum_type=None, containing_type=None,
#     104       is_extension=False, extension_scope=None,
#     105       serialized_options=None, file=DESCRIPTOR),
#     106     _descriptor.FieldDescriptor(
#     107       name='ignore_groundtruth', full_name='object_detection.protos.EvalConfig.ignore_groundtruth', index=10,
#     108       number=10, type=8, cpp_type=7, label=1,
#     109       has_default_value=True, default_value=False,
#     110       message_type=None, enum_type=None, containing_type=None,
#     111       is_extension=False, extension_scope=None,
#     112       serialized_options=None, file=DESCRIPTOR),
#     113     _descriptor.FieldDescriptor(
#     114       name='use_moving_averages', full_name='object_detection.protos.EvalConfig.use_moving_averages', index=11,
#     115       number=11, type=8, cpp_type=7, label=1,
#     116       has_default_value=True, default_value=False,
#     117       message_type=None, enum_type=None, containing_type=None,
#     118       is_extension=False, extension_scope=None,
#     119       serialized_options=None, file=DESCRIPTOR),
#     120     _descriptor.FieldDescriptor(
#     121       name='eval_instance_masks', full_name='object_detection.protos.EvalConfig.eval_instance_masks', index=12,
#     122       number=12, type=8, cpp_type=7, label=1,
#     123       has_default_value=True, default_value=False,
#     124       message_type=None, enum_type=None, containing_type=None,
#     125       is_extension=False, extension_scope=None,
#     126       serialized_options=None, file=DESCRIPTOR),
#     127     _descriptor.FieldDescriptor(
#     128       name='min_score_threshold', full_name='object_detection.protos.EvalConfig.min_score_threshold', index=13,
#     129       number=13, type=2, cpp_type=6, label=1,
#     130       has_default_value=True, default_value=float(0.5),
#     131       message_type=None, enum_type=None, containing_type=None,
#     132       is_extension=False, extension_scope=None,
#     133       serialized_options=None, file=DESCRIPTOR),
#     134     _descriptor.FieldDescriptor(
#     135       name='max_num_boxes_to_visualize', full_name='object_detection.protos.EvalConfig.max_num_boxes_to_visualize', index=14,
#     136       number=14, type=5, cpp_type=1, label=1,
#     137       has_default_value=True, default_value=20,
#     138       message_type=None, enum_type=None, containing_type=None,
#     139       is_extension=False, extension_scope=None,
#     140       serialized_options=None, file=DESCRIPTOR),
#     141     _descriptor.FieldDescriptor(
#     142       name='skip_scores', full_name='object_detection.protos.EvalConfig.skip_scores', index=15,
#     143       number=15, type=8, cpp_type=7, label=1,
#     144       has_default_value=True, default_value=False,
#     145       message_type=None, enum_type=None, containing_type=None,
#     146       is_extension=False, extension_scope=None,
#     147       serialized_options=None, file=DESCRIPTOR),
#     148     _descriptor.FieldDescriptor(
#     149       name='skip_labels', full_name='object_detection.protos.EvalConfig.skip_labels', index=16,
#     150       number=16, type=8, cpp_type=7, label=1,
#     151       has_default_value=True, default_value=False,
#     152       message_type=None, enum_type=None, containing_type=None,
#     153       is_extension=False, extension_scope=None,
#     154       serialized_options=None, file=DESCRIPTOR),
#     155     _descriptor.FieldDescriptor(
#     156       name='visualize_groundtruth_boxes', full_name='object_detection.protos.EvalConfig.visualize_groundtruth_boxes', index=17,
#     157       number=17, type=8, cpp_type=7, label=1,
#     158       has_default_value=True, default_value=False,
#     159       message_type=None, enum_type=None, containing_type=None,
#     160       is_extension=False, extension_scope=None,
#     161       serialized_options=None, file=DESCRIPTOR),
#     162     _descriptor.FieldDescriptor(
#     163       name='groundtruth_box_visualization_color', full_name='object_detection.protos.EvalConfig.groundtruth_box_visualization_color', index=18,
#     164       number=18, type=9, cpp_type=9, label=1,
#     165       has_default_value=True, default_value=_b("black").decode('utf-8'),
#     166       message_type=None, enum_type=None, containing_type=None,
#     167       is_extension=False, extension_scope=None,
#     168       serialized_options=None, file=DESCRIPTOR),
#     169     _descriptor.FieldDescriptor(
#     170       name='keep_image_id_for_visualization_export', full_name='object_detection.protos.EvalConfig.keep_image_id_for_visualization_export', index=19,
#     171       number=19, type=8, cpp_type=7, label=1,
#     172       has_default_value=True, default_value=False,
#     173       message_type=None, enum_type=None, containing_type=None,
#     174       is_extension=False, extension_scope=None,
#     175       serialized_options=None, file=DESCRIPTOR),
#     176     _descriptor.FieldDescriptor(
#     177       name='retain_original_images', full_name='object_detection.protos.EvalConfig.retain_original_images', index=20,
#     178       number=23, type=8, cpp_type=7, label=1,
#     179       has_default_value=True, default_value=True,
#     180       message_type=None, enum_type=None, containing_type=None,
#     181       is_extension=False, extension_scope=None,
#     182       serialized_options=None, file=DESCRIPTOR),
#     183     _descriptor.FieldDescriptor(
#     184       name='include_metrics_per_category', full_name='object_detection.protos.EvalConfig.include_metrics_per_category', index=21,
#     185       number=24, type=8, cpp_type=7, label=1,
#     186       has_default_value=True, default_value=False,
#     187       message_type=None, enum_type=None, containing_type=None,
#     188       is_extension=False, extension_scope=None,
#     189       serialized_options=None, file=DESCRIPTOR),
#     190   ],
#     191   extensions=[
#     192   ],
#     193   nested_types=[],
#     194   enum_types=[
#     195   ],
#     196   serialized_options=None,
#     197   is_extendable=False,
#     198   syntax='proto2',
#     199   extension_ranges=[],
#     200   oneofs=[
#     201   ],
#     202   serialized_start=64,
#     203   serialized_end=823,
#     204 )
#     206 DESCRIPTOR.message_types_by_name['EvalConfig'] = _EVALCONFIG
#     207 _sym_db.RegisterFileDescriptor(DESCRIPTOR)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\descriptor.py:553, in __new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     551 TYPE_BYTES          = 12
#     552 TYPE_UINT32         = 13
# --> 553 TYPE_ENUM           = 14
#     554 TYPE_SFIXED32       = 15
#     555 TYPE_SFIXED64       = 16
#
# TypeError: Descriptors cannot be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %%
from object_detection.protos import pipeline_pb2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from object_detection.protos import pipeline_pb2
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\object_detection\protos\pipeline_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from object_detection.protos import eval_pb2 as object__detection_dot_protos_dot_eval__pb2
#      17 from object_detection.protos import graph_rewriter_pb2 as object__detection_dot_protos_dot_graph__rewriter__pb2
#      18 from object_detection.protos import input_reader_pb2 as object__detection_dot_protos_dot_input__reader__pb2
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\object_detection\protos\eval_pb2.py:36
#      13 _sym_db = _symbol_database.Default()
#      18 DESCRIPTOR = _descriptor.FileDescriptor(
#      19   name='object_detection/protos/eval.proto',
#      20   package='object_detection.protos',
#    (...)
#      23   serialized_pb=_b('\n\"object_detection/protos/eval.proto\x12\x17object_detection.protos\"\xf7\x05\n\nEvalConfig\x12\x15\n\nbatch_size\x18\x19 \x01(\r:\x01\x31\x12\x1e\n\x12num_visualizations\x18\x01 \x01(\r:\x02\x31\x30\x12\x1e\n\x0cnum_examples\x18\x02 \x01(\r:\x04\x35\x30\x30\x30\x42\x02\x18\x01\x12\x1f\n\x12\x65val_interval_secs\x18\x03 \x01(\r:\x03\x33\x30\x30\x12\x18\n\tmax_evals\x18\x04 \x01(\r:\x01\x30\x42\x02\x18\x01\x12\x19\n\nsave_graph\x18\x05 \x01(\x08:\x05\x66\x61lse\x12\"\n\x18visualization_export_dir\x18\x06 \x01(\t:\x00\x12\x15\n\x0b\x65val_master\x18\x07 \x01(\t:\x00\x12\x13\n\x0bmetrics_set\x18\x08 \x03(\t\x12\x15\n\x0b\x65xport_path\x18\t \x01(\t:\x00\x12!\n\x12ignore_groundtruth\x18\n \x01(\x08:\x05\x66\x61lse\x12\"\n\x13use_moving_averages\x18\x0b \x01(\x08:\x05\x66\x61lse\x12\"\n\x13\x65val_instance_masks\x18\x0c \x01(\x08:\x05\x66\x61lse\x12 \n\x13min_score_threshold\x18\r \x01(\x02:\x03\x30.5\x12&\n\x1amax_num_boxes_to_visualize\x18\x0e \x01(\x05:\x02\x32\x30\x12\x1a\n\x0bskip_scores\x18\x0f \x01(\x08:\x05\x66\x61lse\x12\x1a\n\x0bskip_labels\x18\x10 \x01(\x08:\x05\x66\x61lse\x12*\n\x1bvisualize_groundtruth_boxes\x18\x11 \x01(\x08:\x05\x66\x61lse\x12\x32\n#groundtruth_box_visualization_color\x18\x12 \x01(\t:\x05\x62lack\x12\x35\n&keep_image_id_for_visualization_export\x18\x13 \x01(\x08:\x05\x66\x61lse\x12$\n\x16retain_original_images\x18\x17 \x01(\x08:\x04true\x12+\n\x1cinclude_metrics_per_category\x18\x18 \x01(\x08:\x05\x66\x61lse')
#      24 )
#      29 _EVALCONFIG = _descriptor.Descriptor(
#      30   name='EvalConfig',
#      31   full_name='object_detection.protos.EvalConfig',
#      32   filename=None,
#      33   file=DESCRIPTOR,
#      34   containing_type=None,
#      35   fields=[
# ---> 36     _descriptor.FieldDescriptor(
#      37       name='batch_size', full_name='object_detection.protos.EvalConfig.batch_size', index=0,
#      38       number=25, type=13, cpp_type=3, label=1,
#      39       has_default_value=True, default_value=1,
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
#      42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='num_visualizations', full_name='object_detection.protos.EvalConfig.num_visualizations', index=1,
#      45       number=1, type=13, cpp_type=3, label=1,
#      46       has_default_value=True, default_value=10,
#      47       message_type=None, enum_type=None, containing_type=None,
#      48       is_extension=False, extension_scope=None,
#      49       serialized_options=None, file=DESCRIPTOR),
#      50     _descriptor.FieldDescriptor(
#      51       name='num_examples', full_name='object_detection.protos.EvalConfig.num_examples', index=2,
#      52       number=2, type=13, cpp_type=3, label=1,
#      53       has_default_value=True, default_value=5000,
#      54       message_type=None, enum_type=None, containing_type=None,
#      55       is_extension=False, extension_scope=None,
#      56       serialized_options=_b('\030\001'), file=DESCRIPTOR),
#      57     _descriptor.FieldDescriptor(
#      58       name='eval_interval_secs', full_name='object_detection.protos.EvalConfig.eval_interval_secs', index=3,
#      59       number=3, type=13, cpp_type=3, label=1,
#      60       has_default_value=True, default_value=300,
#      61       message_type=None, enum_type=None, containing_type=None,
#      62       is_extension=False, extension_scope=None,
#      63       serialized_options=None, file=DESCRIPTOR),
#      64     _descriptor.FieldDescriptor(
#      65       name='max_evals', full_name='object_detection.protos.EvalConfig.max_evals', index=4,
#      66       number=4, type=13, cpp_type=3, label=1,
#      67       has_default_value=True, default_value=0,
#      68       message_type=None, enum_type=None, containing_type=None,
#      69       is_extension=False, extension_scope=None,
#      70       serialized_options=_b('\030\001'), file=DESCRIPTOR),
#      71     _descriptor.FieldDescriptor(
#      72       name='save_graph', full_name='object_detection.protos.EvalConfig.save_graph', index=5,
#      73       number=5, type=8, cpp_type=7, label=1,
#      74       has_default_value=True, default_value=False,
#      75       message_type=None, enum_type=None, containing_type=None,
#      76       is_extension=False, extension_scope=None,
#      77       serialized_options=None, file=DESCRIPTOR),
#      78     _descriptor.FieldDescriptor(
#      79       name='visualization_export_dir', full_name='object_detection.protos.EvalConfig.visualization_export_dir', index=6,
#      80       number=6, type=9, cpp_type=9, label=1,
#      81       has_default_value=True, default_value=_b("").decode('utf-8'),
#      82       message_type=None, enum_type=None, containing_type=None,
#      83       is_extension=False, extension_scope=None,
#      84       serialized_options=None, file=DESCRIPTOR),
#      85     _descriptor.FieldDescriptor(
#      86       name='eval_master', full_name='object_detection.protos.EvalConfig.eval_master', index=7,
#      87       number=7, type=9, cpp_type=9, label=1,
#      88       has_default_value=True, default_value=_b("").decode('utf-8'),
#      89       message_type=None, enum_type=None, containing_type=None,
#      90       is_extension=False, extension_scope=None,
#      91       serialized_options=None, file=DESCRIPTOR),
#      92     _descriptor.FieldDescriptor(
#      93       name='metrics_set', full_name='object_detection.protos.EvalConfig.metrics_set', index=8,
#      94       number=8, type=9, cpp_type=9, label=3,
#      95       has_default_value=False, default_value=[],
#      96       message_type=None, enum_type=None, containing_type=None,
#      97       is_extension=False, extension_scope=None,
#      98       serialized_options=None, file=DESCRIPTOR),
#      99     _descriptor.FieldDescriptor(
#     100       name='export_path', full_name='object_detection.protos.EvalConfig.export_path', index=9,
#     101       number=9, type=9, cpp_type=9, label=1,
#     102       has_default_value=True, default_value=_b("").decode('utf-8'),
#     103       message_type=None, enum_type=None, containing_type=None,
#     104       is_extension=False, extension_scope=None,
#     105       serialized_options=None, file=DESCRIPTOR),
#     106     _descriptor.FieldDescriptor(
#     107       name='ignore_groundtruth', full_name='object_detection.protos.EvalConfig.ignore_groundtruth', index=10,
#     108       number=10, type=8, cpp_type=7, label=1,
#     109       has_default_value=True, default_value=False,
#     110       message_type=None, enum_type=None, containing_type=None,
#     111       is_extension=False, extension_scope=None,
#     112       serialized_options=None, file=DESCRIPTOR),
#     113     _descriptor.FieldDescriptor(
#     114       name='use_moving_averages', full_name='object_detection.protos.EvalConfig.use_moving_averages', index=11,
#     115       number=11, type=8, cpp_type=7, label=1,
#     116       has_default_value=True, default_value=False,
#     117       message_type=None, enum_type=None, containing_type=None,
#     118       is_extension=False, extension_scope=None,
#     119       serialized_options=None, file=DESCRIPTOR),
#     120     _descriptor.FieldDescriptor(
#     121       name='eval_instance_masks', full_name='object_detection.protos.EvalConfig.eval_instance_masks', index=12,
#     122       number=12, type=8, cpp_type=7, label=1,
#     123       has_default_value=True, default_value=False,
#     124       message_type=None, enum_type=None, containing_type=None,
#     125       is_extension=False, extension_scope=None,
#     126       serialized_options=None, file=DESCRIPTOR),
#     127     _descriptor.FieldDescriptor(
#     128       name='min_score_threshold', full_name='object_detection.protos.EvalConfig.min_score_threshold', index=13,
#     129       number=13, type=2, cpp_type=6, label=1,
#     130       has_default_value=True, default_value=float(0.5),
#     131       message_type=None, enum_type=None, containing_type=None,
#     132       is_extension=False, extension_scope=None,
#     133       serialized_options=None, file=DESCRIPTOR),
#     134     _descriptor.FieldDescriptor(
#     135       name='max_num_boxes_to_visualize', full_name='object_detection.protos.EvalConfig.max_num_boxes_to_visualize', index=14,
#     136       number=14, type=5, cpp_type=1, label=1,
#     137       has_default_value=True, default_value=20,
#     138       message_type=None, enum_type=None, containing_type=None,
#     139       is_extension=False, extension_scope=None,
#     140       serialized_options=None, file=DESCRIPTOR),
#     141     _descriptor.FieldDescriptor(
#     142       name='skip_scores', full_name='object_detection.protos.EvalConfig.skip_scores', index=15,
#     143       number=15, type=8, cpp_type=7, label=1,
#     144       has_default_value=True, default_value=False,
#     145       message_type=None, enum_type=None, containing_type=None,
#     146       is_extension=False, extension_scope=None,
#     147       serialized_options=None, file=DESCRIPTOR),
#     148     _descriptor.FieldDescriptor(
#     149       name='skip_labels', full_name='object_detection.protos.EvalConfig.skip_labels', index=16,
#     150       number=16, type=8, cpp_type=7, label=1,
#     151       has_default_value=True, default_value=False,
#     152       message_type=None, enum_type=None, containing_type=None,
#     153       is_extension=False, extension_scope=None,
#     154       serialized_options=None, file=DESCRIPTOR),
#     155     _descriptor.FieldDescriptor(
#     156       name='visualize_groundtruth_boxes', full_name='object_detection.protos.EvalConfig.visualize_groundtruth_boxes', index=17,
#     157       number=17, type=8, cpp_type=7, label=1,
#     158       has_default_value=True, default_value=False,
#     159       message_type=None, enum_type=None, containing_type=None,
#     160       is_extension=False, extension_scope=None,
#     161       serialized_options=None, file=DESCRIPTOR),
#     162     _descriptor.FieldDescriptor(
#     163       name='groundtruth_box_visualization_color', full_name='object_detection.protos.EvalConfig.groundtruth_box_visualization_color', index=18,
#     164       number=18, type=9, cpp_type=9, label=1,
#     165       has_default_value=True, default_value=_b("black").decode('utf-8'),
#     166       message_type=None, enum_type=None, containing_type=None,
#     167       is_extension=False, extension_scope=None,
#     168       serialized_options=None, file=DESCRIPTOR),
#     169     _descriptor.FieldDescriptor(
#     170       name='keep_image_id_for_visualization_export', full_name='object_detection.protos.EvalConfig.keep_image_id_for_visualization_export', index=19,
#     171       number=19, type=8, cpp_type=7, label=1,
#     172       has_default_value=True, default_value=False,
#     173       message_type=None, enum_type=None, containing_type=None,
#     174       is_extension=False, extension_scope=None,
#     175       serialized_options=None, file=DESCRIPTOR),
#     176     _descriptor.FieldDescriptor(
#     177       name='retain_original_images', full_name='object_detection.protos.EvalConfig.retain_original_images', index=20,
#     178       number=23, type=8, cpp_type=7, label=1,
#     179       has_default_value=True, default_value=True,
#     180       message_type=None, enum_type=None, containing_type=None,
#     181       is_extension=False, extension_scope=None,
#     182       serialized_options=None, file=DESCRIPTOR),
#     183     _descriptor.FieldDescriptor(
#     184       name='include_metrics_per_category', full_name='object_detection.protos.EvalConfig.include_metrics_per_category', index=21,
#     185       number=24, type=8, cpp_type=7, label=1,
#     186       has_default_value=True, default_value=False,
#     187       message_type=None, enum_type=None, containing_type=None,
#     188       is_extension=False, extension_scope=None,
#     189       serialized_options=None, file=DESCRIPTOR),
#     190   ],
#     191   extensions=[
#     192   ],
#     193   nested_types=[],
#     194   enum_types=[
#     195   ],
#     196   serialized_options=None,
#     197   is_extendable=False,
#     198   syntax='proto2',
#     199   extension_ranges=[],
#     200   oneofs=[
#     201   ],
#     202   serialized_start=64,
#     203   serialized_end=823,
#     204 )
#     206 DESCRIPTOR.message_types_by_name['EvalConfig'] = _EVALCONFIG
#     207 _sym_db.RegisterFileDescriptor(DESCRIPTOR)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\descriptor.py:553, in __new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     551 TYPE_BYTES          = 12
#     552 TYPE_UINT32         = 13
# --> 553 TYPE_ENUM           = 14
#     554 TYPE_SFIXED32       = 15
#     555 TYPE_SFIXED64       = 16
#
# TypeError: Descriptors cannot be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %%
pipeline_config.model.ssd.num_classes = 5
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = PRETRAINED_MODEL_PATH+'/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0'
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/train.record']
pipeline_config.eval_input_reader[0].label_map_path = ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/test.record']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 pipeline_config.model.ssd.num_classes = 5
#       2 pipeline_config.train_config.batch_size = 4
#       3 pipeline_config.train_config.fine_tune_checkpoint = PRETRAINED_MODEL_PATH+'/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0'
#
# NameError: name 'pipeline_config' is not defined

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(CONFIG_PATH, "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 config_text = text_format.MessageToString(pipeline_config)
#       2 with tf.io.gfile.GFile(CONFIG_PATH, "wb") as f:
#       3     f.write(config_text)
#
# NameError: name 'text_format' is not defined

# %% [markdown]
# # 6. Train the model

# %%
print("""python {}/research/object_detection/model_main_tf2.py --model_dir={}/{} --pipeline_config_path={}/{}/pipeline.config --num_train_steps=5000""".format(APIMODEL_PATH, MODEL_PATH,CUSTOM_MODEL_NAME,MODEL_PATH,CUSTOM_MODEL_NAME))
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --num_train_steps=5000

# %% [markdown]
# # 7. Load Train Model From Checkpoint

# %%
import os
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 2
#       1 import os
# ----> 2 from object_detection.utils import label_map_util
#       3 from object_detection.utils import visualization_utils as viz_utils
#       4 from object_detection.builders import model_builder
#
# ModuleNotFoundError: No module named 'object_detection'

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(CONFIG_PATH)
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(CHECKPOINT_PATH, 'ckpt-6')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Load pipeline config and build a detection model
# ----> 2 configs = config_util.get_configs_from_pipeline_file(CONFIG_PATH)
#       3 detection_model = model_builder.build(model_config=configs['model'], is_training=False)
#       5 # Restore checkpoint
#
# NameError: name 'config_util' is not defined

# %% [markdown]
# # 8. Detect in Real-Time

# %%
import cv2 
import numpy as np

# %%
category_index = label_map_util.create_category_index_from_labelmap(ANNOTATION_PATH+'/label_map.pbtxt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 category_index = label_map_util.create_category_index_from_labelmap(ANNOTATION_PATH+'/label_map.pbtxt')
#
# NameError: name 'label_map_util' is not defined

# %%
cap.release()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 cap.release()
#
# NameError: name 'cap' is not defined

# %%
# Setup capture
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# %%
while True: 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.5,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        cap.release()
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 6
#       3 image_np = np.array(frame)
#       5 input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
# ----> 6 detections = detect_fn(input_tensor)
#       8 num_detections = int(detections.pop('num_detections'))
#       9 detections = {key: value[0, :num_detections].numpy()
#      10               for key, value in detections.items()}
#
# NameError: name 'detect_fn' is not defined

# %%
detections = detect_fn(input_tensor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 detections = detect_fn(input_tensor)
#
# NameError: name 'detect_fn' is not defined

# %%
from matplotlib import pyplot as plt
